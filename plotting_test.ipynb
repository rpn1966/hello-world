# %% [markdown]
# <a href="https://colab.research.google.com/github/rpn1966/hello-world/blob/main/plotting_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%matplotlib notebook
#!pip install mpld3
import numpy as np
import matplotlib.pyplot as plt
import mpld3
mpld3.enable_notebook()
plt.rcParams['figure.figsize'] = [9.5,6]
xrand = np.random.randn(100)
yrand = np.random.randn(100)
plt.plot(xrand,yrand,'r.')
